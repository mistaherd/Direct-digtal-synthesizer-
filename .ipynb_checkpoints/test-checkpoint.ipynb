# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# fname="outputofrom_fullwave.lst"
# fname="outputfrom_halfwave.lst"
# fname="outputfrom_quaterwave.lst"
#fname="part6.lst"
fname="part6_fix.lst"
with open(fname, 'r') as file:
    lines = file.readlines()  # Read all lines into a list
    items = [line.strip() for line in lines]  # Remove newline characters and
output=[items[i].split() for i in range(len(items))]
#print(output)
output=output[3:]
#header=["ps","Delta","clkin","datain","dataout","testout"]
header=["ps","Delta","clkin","data_port_A","LFSR_OUTPUT","LFSR_BUS","ASK_OUT","LUT_OUT"]
for i in range(len(output)):
    output[i][0]=int(output[i][0])*10**-9
df =pd.DataFrame(data=output,columns=header,index=None)
time_bins=df.ps.to_list()
output_lut=df.ASK_OUT.to_list()
output_lut=["00000000" if output_lut[i]=="UUUUUUUU" else output_lut[i]  for i in range(len(output_lut))]
def reverse_two_complement(bin_string):
    decimal = int(bin_string, 2) - 1  # Convert to decimal, subtract 1i
    flipped_binary=~decimal
#    flipped_binary=''.join(('0'if bin(10)[2:][i]=='1'else '1' for i in range(len(bin(10))-2)))#lp bits
#    if flipped_binary[0]=='1':
 #       flipped_binary=int(flipped_binary)*-1
#    else:
#        flipped_binary=int(flipped_binary)
    return flipped_binary
output=[]
for i in range(len(output_lut)):
    if int(output_lut[i],2)<8:
        output.append(int(output_lut[i],2))
    else:
        output.append(reverse_two_complement(output_lut[i]))
mav_hn=np.ones(7)/7
output=np.convolve(output,mav_hn,mode="same")
plt.plot(time_bins,output)
plt.xlabel("time in nano seconds")
plt.ylabel("Amplitude ")
plt.show()
yf=np.abs(np.fft.fft(output))
xf=np.fft.fftfreq(len(output),1/2**10)
plt.stem(xf,yf)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pylab as plt
import sys
def sine_wave_cycle_logic(choice:int):
    if choice==0:
        N=2**10
        t=np.linspace(0,N,32)
        fs=1
        output= np.sin(2*np.pi*fs*t)+12
        output=output.astype(np.uint10)
    elif choice==1:
        N=2**8
        t=np.linspace(0,1,N)
        fs=1
        output= np.sin(2*np.pi*fs*t)
        output=np.round(output*15).astype(np.uint8)[:32]
    elif choice==2:
        N=2**7
        t=np.linspace(0,1,N)
        fs=1
        output= np.sin(2*np.pi*fs*t)
        output=np.round(output*15).astype(np.uint8)[:32]
    else:
        print("0: full cycle sine wave \n1: half cycle sine wave")
        return None

    return output
def complement_2s(data):
    ones=bin(~data).removeprefix("-0b")
    twos=list(ones)
    for i in range(len(ones)-1,-1,-1):
        if (ones[i]=='1'):
            twos[i]='0'
        else:
            twos[i]='1'
    if (i== -1):
        twos.insert(0,'1')
    twos="".join(twos)
    return twos

output=sine_wave_cycle_logic(0)
lut_out=[]
for i in range(0,len(output),3):
    lut_out.append(output[i])
# mav=np.ones(3)/3
# lut_out=np.convolve(lut_out,mav,mode="same")
plt.plot(lut_out)
plt.plot(output)
plt.show()
print(lut_out)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 41
#      38     twos="".join(twos)
#      39     return twos
# ---> 41 output=sine_wave_cycle_logic(0)
#      42 lut_out=[]
#      43 for i in range(0,len(output),3):
#
# Cell In[3], line 10, in sine_wave_cycle_logic(choice)
#       8     fs=1
#       9     output= np.sin(2*np.pi*fs*t)+12
# ---> 10     output=output.astype(np.uint9)
#      11 elif choice==1:
#      12     N=2**8
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'uint9'
